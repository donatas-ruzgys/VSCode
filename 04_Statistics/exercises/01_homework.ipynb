# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("faresashraf1001/supermarket-sales")

print("Path to dataset files:", path)

# %%
import os
from pathlib import Path

os.getcwd()

# %%
import secrets
import hashlib
import base64

# Generate a random code_verifier (43-128 characters)
code_verifier = secrets.token_urlsafe(32)

# Create code_challenge using SHA-256
code_challenge = base64.urlsafe_b64encode(
    hashlib.sha256(code_verifier.encode()).digest()
).decode().rstrip('=')

# %%
import kagglehub
export KAGGLE_API_TOKEN=KGAT_18aed135ac6573df15e36a8a86e50ef8
# Out:
#   Cell In[14], line 2
#     export KAGGLE_API_TOKEN=KGAT_18aed135ac6573df15e36a8a86e50ef8
#            ^
# SyntaxError: invalid syntax

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "c:\\Users\\donat\\iCloudDrive\\Documents\\BIT Data Analytics\\practice\\VSCode\\04_Statistics\\exercises\\data\\SuperMarket Analysis.csv"

# Load the latest version
df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "faresashraf1001/supermarket-sales",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\donat\iCloudDrive\Documents\BIT Data Analytics\practice\VSCode\.venv\Lib\site-packages\kagglehub\exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File c:\Users\donat\iCloudDrive\Documents\BIT Data Analytics\practice\VSCode\.venv\Lib\site-packages\kagglehub\http_resolver.py:144, in DatasetHttpResolver._resolve.<locals>.<lambda>()
#     143 os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 144 response = handle_call(lambda: api_client.datasets.dataset_api_client.download_dataset(r), h)
#     145 download_file(response, out_path, h, extract_auto_compressed_file=True)
#
# ...
