# %% [markdown]
# ### Task 1.
#
# Write code that:
# - Allows the user to input numbers a and b (int or float)
# - Prints "a is less than b" if that is true
# - Prints "a is equal to b" if that is true
# - Prints "a is greater than b" if that is true
#
# Tip: Use input, if, elif, and else statements

# %%
# Task 1. Solution

a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

if a < b:
    print(f"{a} is less than {b}")
elif a > b:
    print(f"{a} is greater than {b}")
else :
    print(f"{a} is equal to {b}")
# Out:
# 4 is equal to 4

# %% [markdown]
# ### Task 2.
#
# Parašyti kodą, kuris su eilute "Zen of Python" darytų šiuos veiksmus:
# - Atspausdintų paskutinį antro žodžio simbolį
# - Atspausdintų pirmą trečio žodžio simbolį
# - Atspausdintų tik pirmą žodį
# - Atspausdintų tik paskutinį žodį
# - Atspausdintų visą frazę atbulai
# - Atskirtų žodžius ir juos atspausdintų
# - Žodį "Python" pakeistų į "Programming" ir atspausdintų naują sakinį
#
# Patarimas: naudoti string karpymo įrankius, funkcijas split(), replace()
# The Zen of Python:

# %%
# Task 2. Solution

zen_of_python = "Zen of Python"
print(zen_of_python.split(" ")[1][-1])
print(zen_of_python)
print(zen_of_python)
print(zen_of_python)
print(zen_of_python)
print(zen_of_python)
print(zen_of_python)

# %% [markdown]
# ### Task 3.
#
# Programoje išbandyti daugiau string funkcijų:
# - upper()
# - casefold()
# - capitalize()
# - count()
# - find()
# - ir t.t.
#
# Visas jas galite rasti čia: https://www.w3schools.com/python/python_ref_string.asp

# %%
# Task 3. Solution

zen_of_python = "Zen of Python"
print(zen_of_python.upper())
print(zen_of_python.casefold())
print(zen_of_python.capitalize())
print(zen_of_python.count("o"))   # 2
print(zen_of_python.find("P"))  # 7
# TODO
print(zen_of_python)
#print(zen_of_python)
# Out:
# ZEN OF PYTHON
# zen of python
# Zen of python
# 2
# 7
# Zen of Python

# %% [markdown]
# ### Task 4.
#
# Parašyti programą, kuri:
# - Leistų įvesti pirmą skaičių
# - Leistų įvesti antrą skaičių
# - Paklaustų, kokį matematinį veiksmą reiktų atliktų
# - Atspausdintų rezultatą: pasirinktų skaičių suma, daugybą ar pan.
#
# Patarimas: naudoti input(), if, print

# %%
# Task 4. Solution

x = int(input("Enter the first number: "))
y = int(input("Enter the second number: "))

operation = input("Enter which math operation should be performed (+, -, *, /): ")

result = 0.0

if operation == "+":
    result = x + y
    print(f"Result is {x + y}")
elif operation == "-":
    print(f"Result is {x - y}")
elif operation == "*":
    print(f"Result is {x * y}")
else:
    print("Invalid")
# Out:
# Invalid
