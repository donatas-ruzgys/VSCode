# %% [markdown]
# # Investor - Flow of Funds - US
#
# Check out [Investor Flow of Funds Exercises Video Tutorial](https://youtu.be/QG6WbOgC9QE) to watch a data scientist go through the exercises

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/rgrp for sharing the dataset.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
url = 'https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv'
df = pd.read_csv(url)
df.head()
# Out:
#          Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0  2011-10-05         -4002          -4499.0           497 -1354.0
# 1  2011-10-12         -7397          -5842.0         -1555   512.0
# 2  2011-10-19         -3292          -3466.0           174  1399.0
# 3  2011-10-26         -3696          -2998.0          -698  2631.0
# 4  2011-12-07         -7956          -5761.0         -2196  1089.0
#
#    Total Bond  Taxable Bond  Municipal Bond    Total
# 0       -5828       -6258.0             430 -11184.0
# 1        3954        3927.0              28  -2931.0
# 2        5652        5102.0             550   3759.0
# 3        4910        4070.0             841   3846.0
# 4        3523        2068.0            1456  -3343.0

# %%
df.dtypes
# Out:
# Date                   str
# Total Equity         int64
# Domestic Equity    float64
# World Equity         int64
# Hybrid             float64
# Total Bond           int64
# Taxable Bond       float64
# Municipal Bond       int64
# Total              float64
# dtype: object

# %%
df.describe().T
# Out:
#                  count         mean           std      min       25%     50%  \
# Total Equity     159.0  7816.427673  14772.255905 -23041.0  -3416.00  6003.0
# Domestic Equity   50.0 -4908.440000   4426.957647 -15411.0  -6394.00 -4591.5
# World Equity     159.0  6526.301887  11120.789050 -16192.0   -968.50  3322.0
# Hybrid            50.0  -648.540000   1508.122623  -5602.0  -1576.25  -567.0
# Total Bond       159.0  6209.238994  10455.112795 -17891.0   -212.00  4945.0
# Taxable Bond      50.0  1170.000000   6180.386825 -17264.0  -2036.00  2996.0
# Municipal Bond   159.0  1328.345912   1913.667580  -3263.0    251.00  1130.0
# Total             50.0 -4621.960000   9175.230856 -37421.0 -10846.75 -2773.5
#
#                       75%      max
# Total Equity     17217.50  54173.0
# Domestic Equity  -2748.75   5629.0
# World Equity     11025.50  41572.0
# Hybrid             388.25   2631.0
# Total Bond       11387.00  40408.0
# Taxable Bond      4685.50  17101.0
# Municipal Bond    2077.00   7412.0
# Total              305.00  10590.0

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %%
# weekly data

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
df = df.set_index('Date')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6208\3837287310.py in ?()
# ----> 1 df = df.set_index('Date')
#       2 df.head()
#
# c:\Users\donat\iCloudDrive\Documents\BIT Data Analytics\practice\VSCode\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6973                     if not found:
#    6974                         missing.append(col)
#    6975
#    6976         if missing:
# -> 6977             raise KeyError(f"None of {missing} are in the columns")
#    6978
#    6979         if inplace:
#    6980             frame = self
#
# KeyError: "None of ['Date'] are in the columns"

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
df.index
# it is a 'object' type
# Out:
# DatetimeIndex(['2011-10-05', '2011-10-12', '2011-10-19', '2011-10-26',
#                '2011-12-07', '2011-12-14', '2011-12-21', '2011-12-28',
#                '2012-12-05', '2012-12-12',
#                ...
#                '2024-06-26', '2024-07-02', '2024-07-10', '2024-07-17',
#                '2024-07-24', '2024-12-04', '2024-12-11', '2024-12-18',
#                '2024-12-24', '2024-12-31'],
#               dtype='datetime64[us]', name='Date', length=159, freq=None)

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %%
df.index = pd.to_datetime(df.index)
type(df.index)
# Out:
# pandas.DatetimeIndex

# %% [markdown]
# ### Step 8.  Change the frequency to monthly, sum the values and assign it to monthly.

# %%
monthly = df.resample('M').sum()
monthly
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6313, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6180, in pandas._libs.tslibs.offsets._validate_to_offset_alias()
#
# ValueError: 'M' is no longer supported for offsets. Please use 'ME' instead.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 monthly = df.resample('M').sum()
#       2 monthly
#
# File c:\Users\donat\iCloudDrive\Documents\BIT Data Analytics\practice\VSCode\.venv\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\donat\iCloudDrive\Documents\BIT Data Analytics\practice\VSCode\.venv\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\donat\iCloudDrive\Documents\BIT Data Analytics\practice\VSCode\.venv\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: M. Failed to parse with error message: ValueError("'M' is no longer supported for offsets. Please use 'ME' instead.")

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
monthly = monthly.dropna()
monthly
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12-31      -26156.0         -23126.0       -3031.0   526.0      9848.0
# 2013-01-31        3661.0          -1627.0        5288.0  2730.0     12149.0
# 2014-04-30       10842.0           1048.0        9794.0  4931.0      8493.0
# 2014-05-31       -2203.0          -8720.0        6518.0  3172.0     13767.0
# 2014-06-30        2319.0          -6546.0        8865.0  4588.0      9715.0
# 2014-07-31       -7051.0         -11128.0        4078.0  2666.0      7506.0
# 2014-08-31        1943.0          -5508.0        7452.0  1885.0      1897.0
# 2014-09-30       -2767.0          -6596.0        3829.0  1599.0      3984.0
# 2014-11-30       -2753.0          -7239.0        4485.0   729.0     14528.0
# 2015-01-31        3471.0          -1164.0        4635.0  1729.0      7368.0
# 2015-02-28        5508.0           3509.0        1999.0  1752.0      9099.0
# 2015-03-31        5691.0          -8176.0       13867.0  2829.0      9138.0
# 2015-04-30         379.0          -4628.0        5007.0   970.0       423.0
#
#             Taxable Bond  Municipal Bond    Total
# Date
# 2012-12-31       12613.0         -2765.0 -15782.0
# 2013-01-31        9414.0          2735.0  18540.0
# 2014-04-30        7193.0          1300.0  24267.0
# 2014-05-31       10192.0          3576.0  14736.0
# 2014-06-30        7551.0          2163.0  16621.0
# 2014-07-31        7026.0           481.0   3122.0
# 2014-08-31       -1013.0          2910.0   5723.0
# 2014-09-30        2479.0          1504.0   2816.0
# 2014-11-30       11566.0          2962.0  12502.0
# 2015-01-31        2762.0          4606.0  12569.0
# 2015-02-28        7443.0          1656.0  16359.0
# 2015-03-31        7267.0          1870.0  17657.0
# 2015-04-30         514.0           -91.0   1772.0

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %%
year = monthly.resample('AS-JAN').sum()
year
# Out:
#             Total Equity  Domestic Equity  World Equity   Hybrid  Total Bond  \
# Date
# 2012-01-01      -26156.0         -23126.0       -3031.0    526.0      9848.0
# 2013-01-01        3661.0          -1627.0        5288.0   2730.0     12149.0
# 2014-01-01         330.0         -44689.0       45021.0  19570.0     59890.0
# 2015-01-01       15049.0         -10459.0       25508.0   7280.0     26028.0
#
#             Taxable Bond  Municipal Bond    Total
# Date
# 2012-01-01       12613.0         -2765.0 -15782.0
# 2013-01-01        9414.0          2735.0  18540.0
# 2014-01-01       44994.0         14896.0  79787.0
# 2015-01-01       17986.0          8041.0  48357.0

# %% [markdown]
# ### BONUS: Create your own question and answer it.
