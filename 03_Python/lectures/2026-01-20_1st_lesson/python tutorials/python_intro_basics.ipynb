# %% [markdown]
# ## 1. Python sintaksė
#
# - Python naudoja įtraukas vietoje riestinių skliaustų.
# - Kiekviena kodo eilutė atlieka aiškų veiksmą.

# %%
print("Hello, world")
# Out:
# Hello, world

# %%
x = 10
y = 5
suma = x + y
suma
print(x)
print(y)
print(suma)
# Out:
# 10
# 5
# 15

# %% [markdown]
# ## 2. Kintamieji
#
# Kintamasis – vardas, priskirtas reikšmei. Tipas nustatomas automatiškai.

# %%
pardavimai = 120
kaina = 4.5
produktas = "Obuoliai"
pardavimai, kaina, produktas
# Out:
# (120, 4.5, 'Obuoliai')

# %% [markdown]
# ## 3. Duomenų tipai
#
# - int
# - float
# - bool
# - str

# %%
kiekis = 10
kaina = 2.99
aktyvus = True
klientas = "Jonas"

type(kiekis), type(kaina), type(aktyvus), type(klientas)
# Out:
# (int, float, bool, str)

# %% [markdown]
# ## 4. Matematiniai operatoriai

# %%
pajamos = 1000
sanaudos = 750
pelnas = pajamos - sanaudos
pelnas
# Out:
# 250

# %%
kvadratas = 5 ** 2
liekana = 17 % 3
kvadratas, liekana
# Out:
# (25, 2)

# %% [markdown]
# ## 5. Supaprastinti priskyrimo operatoriai

# %%
pardavimai = 100
pardavimai += 25
pardavimai
# Out:
# 125

# %% [markdown]
# ## 6. Mutability

# %%
kaina = 10
kaina = kaina + 5
kaina
# Out:
# 15

# %%
sarasas = [100, 150, 200]
sarasas.append(250)
sarasas
# Out:
# [100, 150, 200, 250]

# %% [markdown]
# ## 7. Iterables

# %%
pajamos = [120, 130, 110]
for p in pajamos:
    print(p)
# Out:
# 120
# 130
# 110

# %% [markdown]
# ## 8. Dažniausiai naudojamos funkcijos

# %%
menesio_pardavimai = [200, 180, 220, 210]
len(menesio_pardavimai), sum(menesio_pardavimai), max(menesio_pardavimai)
# Out:
# (4, 810, 220)
